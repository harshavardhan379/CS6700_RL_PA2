# %% [markdown]
# ## TEAM MEMBERS:
# 1. ME20B083
# 2. ME20B138

# %% [markdown]
# # MC REINFORCE - ACROBOT V1

# %% [markdown]
# IMPORTING LIBRARIES

# %%
'''
Installing packages for rendering the game on Colab
'''

# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1
# !pip install git+https://github.com/tensorflow/docs > /dev/null 2>&1
# !pip install gym[classic_control]
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (69.2.0)
# Requirement already satisfied: gym[classic_control] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[classic_control]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[classic_control]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[classic_control]) (0.0.8)
# Collecting pygame==2.1.0 (from gym[classic_control])
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 45.0 MB/s eta 0:00:00
# Installing collected packages: pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed pygame-2.1.0

# %%
'''
A bunch of imports, you don't have to worry about these
'''

import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import namedtuple, deque
import torch.optim as optim
import datetime
import gym
from gym.wrappers.record_video import RecordVideo
import glob
import io
import base64
import matplotlib.pyplot as plt
from IPython.display import HTML
from pyvirtualdisplay import Display
import tensorflow as tf
from IPython import display as ipythondisplay
from PIL import Image
import tensorflow_probability as tfp
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <

# %%
import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
''''
Function to load environment
'''
def LoadingEnv(seed = 0,name = 'CartPole-v1'):
  env = gym.make(name)
  env.seed(seed)
  state_shape = env.observation_space.shape[0]
  no_of_actions = env.action_space.n
  return env,state_shape, no_of_actions

# %% [markdown]
# NETWORK FOR J(θ)

# %%
device  = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
'''
### Q Network & Some 'hyperparameters'

QNetwork1:
Input Layer - 4 nodes (State Shape) \
Hidden Layer 1 - 128 nodes \
Hidden Layer 2 - 64 nodes \
Output Layer - 2 nodes (Action Space) \
Optimizer - zero_grad()
'''

import torch
import torch.nn as nn
import torch.nn.functional as F


'''
Bunch of Hyper parameters
'''

GAMMA = 0.99            # discount factor
LR = 5e-4               # learning rate


'''
similar to Qnetwork , for MC reinforce we have Jnetwork
'''

class JNetwork(nn.Module):

    def __init__(self, state_size, action_size, seed, fc1_units=128, fc2_units=64):
        """Initialize parameters and build model.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_units (int): Number of nodes in first hidden layer
            fc2_units (int): Number of nodes in second hidden layer
        """
        super(JNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)

    def forward(self, state):
        """Build a network that maps state -> action values."""
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# MC REINFORCE AGENT - TYPE 1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
import datetime
import gym

'''
CREATING REINFORCE agent
'''
class REINFORCEAgentType1():
    def __init__(self, state_size, action_size, seed,fc1_units,fc2_units,lr=0.01):
        # PARAMETERS OF AGENT
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        # CREATE A NETWORK
        self.policy_network = JNetwork(state_size, action_size, seed,fc1_units,fc2_units).to(device)
        self.optimizer = optim.Adam(self.policy_network.parameters(), lr=lr)


        self.saved_log_probs = []
        self.rewards = []
        self.states  =[]

    def act(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        logits = self.policy_network(state)

        # WE USE SOFTMAX FOR REINFORCE
        probs = torch.softmax(logits, dim=1)

        # USING TORCH CATEGORICAL DISTRUBTION FOR SMAPLING USING SOFTMAX WEIGHTS
        m = torch.distributions.Categorical(probs)
        action = m.sample()

        # STORING LOG OF OUTPUT POLICY
        self.saved_log_probs.append(m.log_prob(action))

        # RETURNING ACTION
        return action.item()

    def learn(self, gamma):

        # FINDING G(t)
        G = []
        for t in range(len(self.rewards)):
          rewards_t  = self.rewards[t:]
          discounts_t = [gamma ** i for i in range(len(rewards_t) + 1)]
          G.append(sum([a * b for a, b in zip(discounts_t,rewards_t)]))

        policy_loss = []
        for t,log_prob in enumerate(self.saved_log_probs):
            policy_loss.append(-log_prob * G[t])
        policy_loss = torch.cat(policy_loss).sum()

        # doing gradient descent( we need gradient ascent so we use -log_loss as loss)
        self.optimizer.zero_grad()
        policy_loss.backward()
        self.optimizer.step()


        # RESERTING CONTAINERS
        self.saved_log_probs = []
        self.rewards = []
        self.states = []

# %% [markdown]
# ME REINFORCE TYPE II

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
import datetime
import gym

# Define the neural network architecture
class BNetwork(nn.Module):
    def __init__(self, input_size, output_size, seed, fc1_units=128, fc2_units=64):
        super(BNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(input_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Define the REINFORCE agent with baseline
class REINFORCEAgentType2():
    def __init__(self, state_size, action_size, seed, fc1_units=128, fc2_units=64, lr1=0.01, lr2=0.01):
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        # Policy network
        self.policy_network = JNetwork(state_size, action_size, seed, fc1_units, fc2_units).to(device)
        self.optimizer = optim.Adam(self.policy_network.parameters(), lr=lr1)

        # Baseline network (state-value function)
        self.baseline_network = BNetwork(state_size, 1, seed, fc1_units, fc2_units).to(device)
        self.baseline_optimizer = optim.Adam(self.baseline_network.parameters(), lr=lr2)

        self.saved_log_probs = []
        self.rewards = []
        self.states = []

    def act(self, state):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        logits = self.policy_network(state)
        probs = torch.softmax(logits, dim=1)
        m = torch.distributions.Categorical(probs)
        action = m.sample()
        self.saved_log_probs.append(m.log_prob(action))
        return action.item()

    def learn(self, gamma):
        G = []
        for t in range(len(self.rewards)):
            rewards_t = self.rewards[t:]
            discounts_t = [gamma ** i for i in range(len(rewards_t) + 1)]
            G.append(sum([a * b for a, b in zip(discounts_t, rewards_t)]))
        value_loss = []
        for t in range(len(G)-1):
          state = torch.from_numpy(self.states[t]).float().unsqueeze(0).to(device)
          next_state = torch.from_numpy(self.states[t+1]).float().unsqueeze(0).to(device)
          reward = torch.tensor(self.rewards[t], dtype=torch.float32)
          # Compute TD(0) error
          target = reward + gamma * self.baseline_network(next_state)
          prediction = self.baseline_network(state)
          td_error = target - prediction
          # Compute loss and update the value network
          loss = td_error ** 2
          value_loss.append(loss)


        value_loss = torch.cat(value_loss).sum()
        self.baseline_optimizer.zero_grad()
        value_loss.backward()
        self.baseline_optimizer.step()

        policy_loss = []
        for t, log_prob in enumerate(self.saved_log_probs):
            state = torch.from_numpy(self.states[t]).float().unsqueeze(0).to(device)
            advantage = G[t] - self.baseline_network(state)  # Use the same delta calculated for baseline update
            policy_loss.append(-log_prob * advantage)
        policy_loss = torch.cat(policy_loss).sum()

        self.optimizer.zero_grad()
        policy_loss.backward()
        self.optimizer.step()

        # Reset containers
        self.saved_log_probs = []
        self.rewards = []
        self.states = []

# %% [markdown]
# Reinforce Algorithm

# %%
# Define the REINFORCE algorithm
def ReinforceAlgo(env, agent, n_episodes=10000, max_t=1000, gamma=0.99,reward_threshold = 195, flag = True):
    scores_window = deque(maxlen=100)
    rewards_per_episode = []
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        score = 0
        for t in range(max_t):
            agent.states.append(state)
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            # strong rewards for each timpestep of episode
            agent.rewards.append(reward)
            state = next_state
            # net score of episode
            score += reward
            if done:
                break

        scores_window.append(score)
        rewards_per_episode.append(score)

        agent.learn(gamma)

        if i_episode % 100 == 0:
          print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))

        if flag:
          if np.mean(scores_window) >= reward_threshold:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
            break

    return rewards_per_episode

# %% [markdown]
# Defining Hyperparamters and Running Algo

# %%
import torch
import numpy as np
import random
import datetime
'''
 Define hyperparameters
'''

seed = 0
LR1 = 1e-4
LR2 = 1e-4

gamma = 0.99
n_episodes = 5000
max_t = 500
name = 'Acrobot-v1'
fc1_units = 128
fc2_units = 64
reward_threshold = -100
'''
 Function to set device
'''
def set_device():
    return torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Function to run the algorithm
'''
def RunAlgo(variant,fc1_units=fc1_units, fc2_units=fc2_units, seed=seed, LR1=LR1,LR2 = LR2, gamma=gamma, n_episodes=n_episodes,max_t=max_t, name=name, reward_threshold=reward_threshold,flag = True):
    device = set_device()
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    env, state_shape, no_of_actions = LoadingEnv(seed, name)
    if variant == '1':
      agent = REINFORCEAgentType1(state_shape, no_of_actions, seed, fc1_units, fc2_units, LR1)
    else:
      agent = REINFORCEAgentType2(state_shape, no_of_actions, seed, fc1_units, fc2_units, LR1,LR2)
    begin_time = datetime.datetime.now()
    rewards = ReinforceAlgo(env, agent, n_episodes, max_t, gamma, reward_threshold,flag)
    time_taken = datetime.datetime.now() - begin_time
    print(" Time taken:", time_taken)
    env.close()
    return rewards, time_taken

# %%
'''
 Define hyperparameters
'''

seed = 0
LR1 = 1e-4
LR2 = 1e-4

gamma = 0.99
n_episodes = 5000
max_t = 500
name = 'Acrobot-v1'
fc1_units = 128
fc2_units = 64
reward_threshold = -100

# Function for hyperparameter tuning
def hyperparameter_tuning(variant,params):
    results = []
    for param_set in params:
        rewards, time_taken = RunAlgo(variant,**param_set,seed= seed,gamma = gamma, LR2 = LR2, n_episodes=n_episodes,max_t=max_t, name=name, reward_threshold=reward_threshold)
        avg_score = np.mean(rewards)
        avg_time = time_taken.total_seconds()  # Convert timedelta to seconds
        results.append({
            'Hyperparameters': param_set,
            'Average Score': avg_score,
            'Training Time (s)': avg_time,
            'rewards' : rewards
        })
    return results

# Function to generate LaTeX table
def generate_latex_table(results):
    table = "\\begin{table}[h]\n\\centering\n\\begin{tabular}{|c|c|c|}\n\\hline\n"
    table += "Hyperparameters & Average Score & Training Time (s) \\\\\n\\hline\n"
    for result in results:
        table += f"{result['Hyperparameters']} & {result['Average Score']:.2f} & {result['Training Time (s)']:.2f} \\\\\n"
    table += "\\hline\n\\end{tabular}\n\\caption{Hyperparameter Tuning Results}\n\\label{tab:hyperparams}\n\\end{table}"
    return table
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


# Define range of hyperparameters to tune
params_to_tune = [
    {'fc1_units': 128, 'fc2_units': 64, 'LR1': 1e-6},
    {'fc1_units': 128, 'fc2_units': 64, 'LR1': 1e-1},
    {'fc1_units': 128, 'fc2_units': 64, 'LR1': 1e-4 },
    {'fc1_units': 128, 'fc2_units': 128, 'LR1': 1e-4},
    {'fc1_units': 256, 'fc2_units': 128, 'LR1': 1e-4},
    {'fc1_units': 256, 'fc2_units': 256, 'LR1': 1e-4}
]

# Perform hyperparameter tuning
results = hyperparameter_tuning('1',params_to_tune)

# Generate LaTeX table
latex_table = generate_latex_table(results)

# Print LaTeX table
print(latex_table)
# Out:
# Episode 100	Average Score: -494.53
# Episode 200	Average Score: -494.04
# Episode 300	Average Score: -497.83
# Episode 400	Average Score: -496.14
# Episode 500	Average Score: -497.99
# Episode 600	Average Score: -497.27
# Episode 700	Average Score: -495.06
# Episode 800	Average Score: -495.77
# Episode 900	Average Score: -497.33
# Episode 1000	Average Score: -496.18
# Episode 1100	Average Score: -496.25
# Episode 1200	Average Score: -495.07
# Episode 1300	Average Score: -494.31
# Episode 1400	Average Score: -494.61
# Episode 1500	Average Score: -495.70
# Episode 1600	Average Score: -496.49
# Episode 1700	Average Score: -492.30
# Episode 1800	Average Score: -493.56
# Episode 1900	Average Score: -495.64
# Episode 2000	Average Score: -494.41
# Episode 2100	Average Score: -492.05
# Episode 2200	Average Score: -495.47
# Episode 2300	Average Score: -498.53
# Episode 2400	Average Score: -493.08
# Episode 2500	Average Score: -497.59
# Episode 2600	Average Score: -495.50
# Episode 2700	Average Score: -493.95
# Episode 2800	Average Score: -491.96
# Episode 2900	Average Score: -494.86
# Episode 3000	Average Score: -496.47
# Episode 3100	Average Score: -494.64
# Episode 3200	Average Score: -493.13
# Episode 3300	Average Score: -496.95
# Episode 3400	Average Score: -499.88
# Episode 3500	Average Score: -497.80
# Episode 3600	Average Score: -492.24
# Episode 3700	Average Score: -494.93
# Episode 3800	Average Score: -496.35
# Episode 3900	Average Score: -493.97
# Episode 4000	Average Score: -493.53
# Episode 4100	Average Score: -494.47
# Episode 4200	Average Score: -495.26
# Episode 4300	Average Score: -493.25
# Episode 4400	Average Score: -494.99
# Episode 4500	Average Score: -497.49
# Episode 4600	Average Score: -497.06
# Episode 4700	Average Score: -498.37
# Episode 4800	Average Score: -497.51
# Episode 4900	Average Score: -493.85
# Episode 5000	Average Score: -491.60
#  Time taken: 0:59:55.875799
# Episode 100	Average Score: -498.42
# Episode 200	Average Score: -500.00
# Episode 300	Average Score: -500.00
# Episode 400	Average Score: -500.00
# Episode 500	Average Score: -500.00
# Episode 600	Average Score: -500.00
# Episode 700	Average Score: -500.00
# Episode 800	Average Score: -500.00
# Episode 900	Average Score: -500.00
# Episode 1000	Average Score: -500.00
# Episode 1100	Average Score: -500.00
# Episode 1200	Average Score: -500.00
# Episode 1300	Average Score: -500.00
# Episode 1400	Average Score: -500.00
# Episode 1500	Average Score: -500.00
# Episode 1600	Average Score: -500.00
# Episode 1700	Average Score: -500.00
# Episode 1800	Average Score: -500.00
# Episode 1900	Average Score: -500.00
# Episode 2000	Average Score: -500.00
# Episode 2100	Average Score: -500.00
# Episode 2200	Average Score: -500.00
# Episode 2300	Average Score: -500.00
# Episode 2400	Average Score: -500.00
# Episode 2500	Average Score: -500.00
# Episode 2600	Average Score: -500.00
# Episode 2700	Average Score: -500.00
# Episode 2800	Average Score: -500.00
# Episode 2900	Average Score: -500.00
# Episode 3000	Average Score: -500.00
# Episode 3100	Average Score: -500.00
# Episode 3200	Average Score: -500.00
# Episode 3300	Average Score: -500.00
# Episode 3400	Average Score: -500.00
# Episode 3500	Average Score: -500.00
# Episode 3600	Average Score: -500.00
# Episode 3700	Average Score: -500.00
# Episode 3800	Average Score: -500.00
# Episode 3900	Average Score: -500.00
# Episode 4000	Average Score: -500.00
# Episode 4100	Average Score: -500.00
# Episode 4200	Average Score: -500.00
# Episode 4300	Average Score: -500.00
# Episode 4400	Average Score: -500.00
# Episode 4500	Average Score: -500.00
# Episode 4600	Average Score: -500.00
# Episode 4700	Average Score: -500.00
# Episode 4800	Average Score: -500.00
# Episode 4900	Average Score: -500.00
# Episode 5000	Average Score: -500.00
#  Time taken: 1:05:35.264876
# Episode 100	Average Score: -496.18
# Episode 200	Average Score: -493.61
# Episode 300	Average Score: -484.82
# Episode 400	Average Score: -464.65
# Episode 500	Average Score: -391.97
# Episode 600	Average Score: -374.42
# Episode 700	Average Score: -326.06
# Episode 800	Average Score: -317.66
# Episode 900	Average Score: -251.62
# Episode 1000	Average Score: -233.95
# Episode 1100	Average Score: -210.20
# Episode 1200	Average Score: -191.51
# Episode 1300	Average Score: -187.41
# Episode 1400	Average Score: -186.70
# Episode 1500	Average Score: -171.38
# Episode 1600	Average Score: -161.18
# Episode 1700	Average Score: -149.39
# Episode 1800	Average Score: -141.20
# Episode 1900	Average Score: -157.61
# Episode 2000	Average Score: -137.75
# Episode 2100	Average Score: -133.33
# Episode 2200	Average Score: -130.98
# Episode 2300	Average Score: -130.00
# Episode 2400	Average Score: -128.89
# Episode 2500	Average Score: -123.92
# Episode 2600	Average Score: -114.08
# Episode 2700	Average Score: -131.24
# Episode 2800	Average Score: -121.47
# Episode 2900	Average Score: -117.89
# Episode 3000	Average Score: -116.36
# Episode 3100	Average Score: -119.77
# Episode 3200	Average Score: -115.49
# Episode 3300	Average Score: -109.16
# Episode 3400	Average Score: -110.76
# Episode 3500	Average Score: -111.48
# Episode 3600	Average Score: -115.01
# Episode 3700	Average Score: -105.76
# Episode 3800	Average Score: -104.00
# Episode 3900	Average Score: -111.39
# Episode 4000	Average Score: -109.85
# Episode 4100	Average Score: -104.85
# Episode 4200	Average Score: -110.93
# Episode 4300	Average Score: -106.73
# Episode 4400	Average Score: -105.41
# Episode 4500	Average Score: -103.21
# Episode 4600	Average Score: -104.01
# Episode 4700	Average Score: -104.59
# Episode 4800	Average Score: -104.15
# Episode 4900	Average Score: -114.37
# Episode 5000	Average Score: -101.48
#  Time taken: 0:23:52.770821
# Episode 100	Average Score: -499.53
# Episode 200	Average Score: -500.00
# Episode 300	Average Score: -500.00
# Episode 400	Average Score: -500.00
# Episode 500	Average Score: -500.00
# Episode 600	Average Score: -480.95
# Episode 700	Average Score: -384.25
# Episode 800	Average Score: -329.79
# Episode 900	Average Score: -252.41
# Episode 1000	Average Score: -207.24
# Episode 1100	Average Score: -197.43
# Episode 1200	Average Score: -179.47
# Episode 1300	Average Score: -165.86
# Episode 1400	Average Score: -158.61
# Episode 1500	Average Score: -148.75
# Episode 1600	Average Score: -143.14
# Episode 1700	Average Score: -132.74
# Episode 1800	Average Score: -128.59
# Episode 1900	Average Score: -123.86
# Episode 2000	Average Score: -127.26
# Episode 2100	Average Score: -119.44
# Episode 2200	Average Score: -118.21
# Episode 2300	Average Score: -120.91
# Episode 2400	Average Score: -117.60
# Episode 2500	Average Score: -116.46
# Episode 2600	Average Score: -113.71
# Episode 2700	Average Score: -110.40
# Episode 2800	Average Score: -104.46
# Episode 2900	Average Score: -111.78
# Episode 3000	Average Score: -106.53
# Episode 3100	Average Score: -114.89
# Episode 3200	Average Score: -110.08
# Episode 3300	Average Score: -102.36
#
# Environment solved in 3318 episodes!	Average Score: -99.89
#  Time taken: 0:18:37.486018
# Episode 100	Average Score: -446.67
# Episode 200	Average Score: -282.71
# Episode 300	Average Score: -215.81
# Episode 400	Average Score: -174.65
# Episode 500	Average Score: -167.58
# Episode 600	Average Score: -156.13
# Episode 700	Average Score: -138.13
# Episode 800	Average Score: -141.69
# Episode 900	Average Score: -132.81
# Episode 1000	Average Score: -140.49
# Episode 1100	Average Score: -134.36
# Episode 1200	Average Score: -122.61
# Episode 1300	Average Score: -120.39
# Episode 1400	Average Score: -120.71
# Episode 1500	Average Score: -111.50
# Episode 1600	Average Score: -114.60
# Episode 1700	Average Score: -113.27
# Episode 1800	Average Score: -120.37
# Episode 1900	Average Score: -111.09
# Episode 2000	Average Score: -104.99
# Episode 2100	Average Score: -108.99
#
# Environment solved in 2186 episodes!	Average Score: -99.63
#  Time taken: 0:08:29.764965
# Episode 100	Average Score: -444.63
# Episode 200	Average Score: -263.68
# Episode 300	Average Score: -175.67
# Episode 400	Average Score: -151.31
# Episode 500	Average Score: -139.44
# Episode 600	Average Score: -120.04
# Episode 700	Average Score: -119.18
# Episode 800	Average Score: -117.48
# Episode 900	Average Score: -124.31
# Episode 1000	Average Score: -115.65
# Episode 1100	Average Score: -114.50
# Episode 1200	Average Score: -109.37
# Episode 1300	Average Score: -110.42
# Episode 1400	Average Score: -118.19
# Episode 1500	Average Score: -113.64
# Episode 1600	Average Score: -108.53
# Episode 1700	Average Score: -111.57
# Episode 1800	Average Score: -100.68
#
# Environment solved in 1849 episodes!	Average Score: -99.66
#  Time taken: 0:07:02.549969
# \begin{table}[h]
# \centering
# \begin{tabular}{|c|c|c|}
# \hline
# Hyperparameters & Average Score & Training Time (s) \\
# \hline
# {'fc1_units': 128, 'fc2_units': 64, 'LR1': 1e-06} & -495.34 & 3595.88 \\
# {'fc1_units': 128, 'fc2_units': 64, 'LR1': 0.1} & -499.97 & 3935.26 \\
# {'fc1_units': 128, 'fc2_units': 64, 'LR1': 0.0001} & -179.00 & 1432.77 \\
# {'fc1_units': 128, 'fc2_units': 128, 'LR1': 0.0001} & -215.31 & 1117.49 \\
# {'fc1_units': 256, 'fc2_units': 128, 'LR1': 0.0001} & -153.91 & 509.76 \\
# {'fc1_units': 256, 'fc2_units': 256, 'LR1': 0.0001} & -146.45 & 422.55 \\
# \hline
# \end{tabular}
# \caption{Hyperparameter Tuning Results}
# \label{tab:hyperparams}
# \end{table}

# %%
reward_threshold = -100
n_episodes = 1000
max_t = 500
name = 'Acrobot-v1'
seed = 0
best_params  = {'fc1_units': 256, 'fc2_units': 256, 'LR1': 1e-4, 'LR2' : 1e-04 ,'gamma': 0.99}

# %%
rewards, time_taken = RunAlgo('1',**best_params,seed= seed, n_episodes=n_episodes,max_t=max_t, name=name, reward_threshold=reward_threshold,flag = False)
# Out:
# Episode 100	Average Score: -444.63
# Episode 200	Average Score: -263.68
# Episode 300	Average Score: -175.67
# Episode 400	Average Score: -151.31
# Episode 500	Average Score: -139.44
# Episode 600	Average Score: -120.04
# Episode 700	Average Score: -119.18
# Episode 800	Average Score: -117.48
# Episode 900	Average Score: -124.31
# Episode 1000	Average Score: -115.65
#  Time taken: 0:03:42.875868

# %%
plt.plot(rewards, label='Mean Rewards', color='blue')
plt.show()

# %%
reward_threshold = -100
n_episodes = 1000
max_t = 500
name = 'Acrobot-v1'
seed = 0
best_params  = {'fc1_units': 256, 'fc2_units': 256, 'LR1': 1e-4,'LR2' : 1e-04 ,'gamma': 0.99}
rewards, time_taken = RunAlgo('2',**best_params,seed= seed, n_episodes=n_episodes,max_t=max_t, name=name, reward_threshold=reward_threshold,flag = False)
plt.plot(rewards, label='Mean Rewards', color='blue')
plt.show()
# Out:
# Episode 100	Average Score: -427.53
# Episode 200	Average Score: -205.69
# Episode 300	Average Score: -174.44
# Episode 400	Average Score: -150.41
# Episode 500	Average Score: -148.14
# Episode 600	Average Score: -136.35
# Episode 700	Average Score: -118.35
# Episode 800	Average Score: -123.88
# Episode 900	Average Score: -115.66
# Episode 1000	Average Score: -109.99
#  Time taken: 0:06:44.146448

# %%
import numpy as np
import matplotlib.pyplot as plt
reward_threshold = -100
n_episodes = 5000
max_t = 500
name = 'Acrobot-v1'
seed = 0
best_params  = {'fc1_units': 256, 'fc2_units': 256, 'LR1': 1e-4,'LR2' : 1e-04 ,'gamma': 0.99}
# Define function to run algorithm over multiple seeds
def run_multiple_seeds(num_seeds=5):
    all_rewards = []
    all_time_taken = []
    for i in range(num_seeds):
        seed = i
        rewards, time_taken =  RunAlgo('1',**best_params,seed= seed, n_episodes=n_episodes,max_t=max_t, name=name, reward_threshold=reward_threshold,flag = False)
        all_rewards.append(rewards)
        all_time_taken.append(time_taken.total_seconds())
    return all_rewards, all_time_taken

# Run the algorithm over multiple seeds
all_rewards, all_time_taken = run_multiple_seeds()

# Calculate mean and standard deviation of rewards
mean_rewards_1 = np.mean(all_rewards, axis=0)
std_rewards_1 = np.std(all_rewards, axis=0)
upper_bound_1 = mean_rewards_1 + std_rewards_1
lower_bound_1 = mean_rewards_1 - std_rewards_1

# Plot rewards mean along with upper and lower bounds based on standard deviation
plt.figure(figsize=(10, 6))
plt.plot(mean_rewards_1, label='Mean Rewards', color='blue')
plt.fill_between(range(len(mean_rewards_1)), lower_bound_1, upper_bound_1, color='skyblue', alpha=0.3, label='Standard Deviation')
plt.xlabel('Episodes')
plt.ylabel('Average Score')
plt.title('Average Score with Standard Deviation over Episodes (5 seeds)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Episode 100	Average Score: -444.63
# Episode 200	Average Score: -263.68
# Episode 300	Average Score: -175.67
# Episode 400	Average Score: -151.31
# Episode 500	Average Score: -139.44
# Episode 600	Average Score: -120.04
# Episode 700	Average Score: -119.18
# Episode 800	Average Score: -117.48
# Episode 900	Average Score: -124.31
# Episode 1000	Average Score: -115.65
# Episode 1100	Average Score: -114.50
# Episode 1200	Average Score: -109.37
# Episode 1300	Average Score: -110.42
# Episode 1400	Average Score: -118.19
# Episode 1500	Average Score: -113.64
# Episode 1600	Average Score: -108.53
# Episode 1700	Average Score: -111.57
# Episode 1800	Average Score: -100.68
# Episode 1900	Average Score: -101.60
# Episode 2000	Average Score: -105.22
# Episode 2100	Average Score: -101.24
# Episode 2200	Average Score: -101.94
# Episode 2300	Average Score: -108.47
# Episode 2400	Average Score: -98.13
# Episode 2500	Average Score: -99.78
# Episode 2600	Average Score: -94.28
# Episode 2700	Average Score: -97.13
# Episode 2800	Average Score: -93.90
# Episode 2900	Average Score: -97.12
# Episode 3000	Average Score: -97.89
# Episode 3100	Average Score: -94.81
# Episode 3200	Average Score: -99.89
# Episode 3300	Average Score: -99.93
# Episode 3400	Average Score: -92.38
# Episode 3500	Average Score: -99.64
# Episode 3600	Average Score: -94.74
# Episode 3700	Average Score: -92.11
# Episode 3800	Average Score: -97.10
# Episode 3900	Average Score: -101.91
# Episode 4000	Average Score: -97.18
# Episode 4100	Average Score: -92.96
# Episode 4200	Average Score: -92.91
# Episode 4300	Average Score: -89.78
# Episode 4400	Average Score: -87.50
# Episode 4500	Average Score: -93.30
# Episode 4600	Average Score: -85.19
# Episode 4700	Average Score: -89.43
# Episode 4800	Average Score: -86.12
# Episode 4900	Average Score: -91.43
# Episode 5000	Average Score: -87.89
#  Time taken: 0:11:39.814504
# Episode 100	Average Score: -475.43
# Episode 200	Average Score: -313.76
# Episode 300	Average Score: -223.18
# Episode 400	Average Score: -170.79
# Episode 500	Average Score: -162.77
# Episode 600	Average Score: -173.42
# Episode 700	Average Score: -173.29
# Episode 800	Average Score: -156.15
# Episode 900	Average Score: -156.50
# Episode 1000	Average Score: -131.15
# Episode 1100	Average Score: -119.47
# Episode 1200	Average Score: -118.51
# Episode 1300	Average Score: -125.20
# Episode 1400	Average Score: -121.70
# Episode 1500	Average Score: -121.42
# Episode 1600	Average Score: -112.10
# Episode 1700	Average Score: -114.17
# Episode 1800	Average Score: -115.38
# Episode 1900	Average Score: -111.37
# Episode 2000	Average Score: -108.62
# Episode 2100	Average Score: -112.15
# Episode 2200	Average Score: -108.08
# Episode 2300	Average Score: -109.01
# Episode 2400	Average Score: -105.00
# Episode 2500	Average Score: -102.59
# Episode 2600	Average Score: -98.77
# Episode 2700	Average Score: -99.68
# Episode 2800	Average Score: -101.75
# Episode 2900	Average Score: -98.91
# Episode 3000	Average Score: -100.44
# Episode 3100	Average Score: -89.84
# Episode 3200	Average Score: -99.53
# Episode 3300	Average Score: -98.91
# Episode 3400	Average Score: -98.65
# Episode 3500	Average Score: -93.39
# Episode 3600	Average Score: -91.40
# Episode 3700	Average Score: -94.37
# Episode 3800	Average Score: -90.47
# Episode 3900	Average Score: -97.59
# Episode 4000	Average Score: -89.72
# Episode 4100	Average Score: -96.68
# Episode 4200	Average Score: -87.96
# Episode 4300	Average Score: -96.44
# Episode 4400	Average Score: -84.91
# Episode 4500	Average Score: -92.39
# Episode 4600	Average Score: -94.08
# Episode 4700	Average Score: -87.86
# Episode 4800	Average Score: -90.85
# Episode 4900	Average Score: -84.67
# Episode 5000	Average Score: -82.88
#  Time taken: 0:12:34.815494
# Episode 100	Average Score: -500.00
# Episode 200	Average Score: -500.00
# Episode 300	Average Score: -500.00
# Episode 400	Average Score: -500.00
# Episode 500	Average Score: -500.00
# Episode 600	Average Score: -500.00
# Episode 700	Average Score: -498.52
# Episode 800	Average Score: -500.00
# Episode 900	Average Score: -500.00
# Episode 1000	Average Score: -500.00
# Episode 1100	Average Score: -441.98
# Episode 1200	Average Score: -214.82
# Episode 1300	Average Score: -144.16
# Episode 1400	Average Score: -142.27
# Episode 1500	Average Score: -121.83
# Episode 1600	Average Score: -127.79
# Episode 1700	Average Score: -125.37
# Episode 1800	Average Score: -124.54
# Episode 1900	Average Score: -116.75
# Episode 2000	Average Score: -110.52
# Episode 2100	Average Score: -110.04
# Episode 2200	Average Score: -105.48
# Episode 2300	Average Score: -108.75
# Episode 2400	Average Score: -111.26
# Episode 2500	Average Score: -103.64
# Episode 2600	Average Score: -103.21
# Episode 2700	Average Score: -102.18
# Episode 2800	Average Score: -99.15
# Episode 2900	Average Score: -98.82
# Episode 3000	Average Score: -103.01
# Episode 3100	Average Score: -106.12
# Episode 3200	Average Score: -104.23
# Episode 3300	Average Score: -100.99
# Episode 3400	Average Score: -96.98
# Episode 3500	Average Score: -102.14
# Episode 3600	Average Score: -99.73
# Episode 3700	Average Score: -91.39
# Episode 3800	Average Score: -94.70
# Episode 3900	Average Score: -95.32
# Episode 4000	Average Score: -95.19
# Episode 4100	Average Score: -90.60
# Episode 4200	Average Score: -90.66
# Episode 4300	Average Score: -91.69
# Episode 4400	Average Score: -89.25
# Episode 4500	Average Score: -93.01
# Episode 4600	Average Score: -89.19
# Episode 4700	Average Score: -93.93
# Episode 4800	Average Score: -83.22
# Episode 4900	Average Score: -90.87
# Episode 5000	Average Score: -90.45
#  Time taken: 0:19:49.044164
# Episode 100	Average Score: -479.46
# Episode 200	Average Score: -348.80
# Episode 300	Average Score: -243.15
# Episode 400	Average Score: -186.18
# Episode 500	Average Score: -172.14
# Episode 600	Average Score: -147.91
# Episode 700	Average Score: -138.46
# Episode 800	Average Score: -135.34
# Episode 900	Average Score: -135.52
# Episode 1000	Average Score: -133.05
# Episode 1100	Average Score: -124.25
# Episode 1200	Average Score: -137.34
# Episode 1300	Average Score: -137.91
# Episode 1400	Average Score: -128.55
# Episode 1500	Average Score: -118.02
# Episode 1600	Average Score: -120.01
# Episode 1700	Average Score: -122.37
# Episode 1800	Average Score: -121.97
# Episode 1900	Average Score: -109.83
# Episode 2000	Average Score: -113.49
# Episode 2100	Average Score: -110.53
# Episode 2200	Average Score: -107.91
# Episode 2300	Average Score: -109.64
# Episode 2400	Average Score: -106.76
# Episode 2500	Average Score: -109.54
# Episode 2600	Average Score: -109.46
# Episode 2700	Average Score: -112.34
# Episode 2800	Average Score: -114.27
# Episode 2900	Average Score: -108.80
# Episode 3000	Average Score: -103.63
# Episode 3100	Average Score: -105.65
# Episode 3200	Average Score: -102.46
# Episode 3300	Average Score: -106.91
# Episode 3400	Average Score: -99.72
# Episode 3500	Average Score: -105.56
# Episode 3600	Average Score: -98.25
# Episode 3700	Average Score: -93.51
# Episode 3800	Average Score: -95.42
# Episode 3900	Average Score: -100.89
# Episode 4000	Average Score: -96.43
# Episode 4100	Average Score: -94.21
# Episode 4200	Average Score: -88.29
# Episode 4300	Average Score: -88.58
# Episode 4400	Average Score: -99.15
# Episode 4500	Average Score: -91.52
# Episode 4600	Average Score: -99.12
# Episode 4700	Average Score: -88.28
# Episode 4800	Average Score: -94.08
# Episode 4900	Average Score: -93.94
# Episode 5000	Average Score: -91.35
#  Time taken: 0:12:57.218299
# Episode 100	Average Score: -423.20
# Episode 200	Average Score: -253.02
# Episode 300	Average Score: -224.04
# Episode 400	Average Score: -220.15
# Episode 500	Average Score: -227.32
# Episode 600	Average Score: -200.80
# Episode 700	Average Score: -161.74
# Episode 800	Average Score: -151.06
# Episode 900	Average Score: -146.61
# Episode 1000	Average Score: -151.59
# Episode 1100	Average Score: -145.17
# Episode 1200	Average Score: -123.58
# Episode 1300	Average Score: -125.01
# Episode 1400	Average Score: -110.65
# Episode 1500	Average Score: -113.18
# Episode 1600	Average Score: -116.53
# Episode 1700	Average Score: -109.63
# Episode 1800	Average Score: -108.23
# Episode 1900	Average Score: -106.12
# Episode 2000	Average Score: -105.45
# Episode 2100	Average Score: -103.16
# Episode 2200	Average Score: -100.85
# Episode 2300	Average Score: -102.66
# Episode 2400	Average Score: -94.48
# Episode 2500	Average Score: -99.91
# Episode 2600	Average Score: -96.08
# Episode 2700	Average Score: -93.71
# Episode 2800	Average Score: -92.81
# Episode 2900	Average Score: -91.50
# Episode 3000	Average Score: -99.03
# Episode 3100	Average Score: -98.31
# Episode 3200	Average Score: -94.52
# Episode 3300	Average Score: -100.52
# Episode 3400	Average Score: -99.37
# Episode 3500	Average Score: -87.68
# Episode 3600	Average Score: -90.43
# Episode 3700	Average Score: -94.06
# Episode 3800	Average Score: -94.06
# Episode 3900	Average Score: -88.51
# Episode 4000	Average Score: -94.71
# Episode 4100	Average Score: -95.26
# Episode 4200	Average Score: -96.05
# Episode 4300	Average Score: -98.91
# Episode 4400	Average Score: -88.52
# Episode 4500	Average Score: -89.35
# Episode 4600	Average Score: -87.61
# Episode 4700	Average Score: -90.69
# Episode 4800	Average Score: -90.94
# Episode 4900	Average Score: -90.25
# Episode 5000	Average Score: -90.82
#  Time taken: 0:12:32.248661

# %%
import numpy as np
import matplotlib.pyplot as plt
reward_threshold = -100
n_episodes = 5000
max_t = 500
name = 'Acrobot-v1'
seed = 0
best_params  = {'fc1_units': 256, 'fc2_units': 256, 'LR1': 1e-4,'LR2' : 1e-04 ,'gamma': 0.99}
# Define function to run algorithm over multiple seeds
def run_multiple_seeds(num_seeds=5):
    all_rewards = []
    all_time_taken = []
    for i in range(num_seeds):
        seed = i
        rewards, time_taken =  RunAlgo('2',**best_params,seed= seed, n_episodes=n_episodes,max_t=max_t, name=name, reward_threshold=reward_threshold,flag = False)
        all_rewards.append(rewards)
        all_time_taken.append(time_taken.total_seconds())
    return all_rewards, all_time_taken

# Run the algorithm over multiple seeds
all_rewards, all_time_taken = run_multiple_seeds()

# Calculate mean and standard deviation of rewards
mean_rewards_2 = np.mean(all_rewards, axis=0)
std_rewards_2 = np.std(all_rewards, axis=0)
upper_bound_2 = mean_rewards_2 + std_rewards_2
lower_bound_2 = mean_rewards_2 - std_rewards_2

# Plot rewards mean along with upper and lower bounds based on standard deviation
plt.figure(figsize=(10, 6))
plt.plot(mean_rewards_2, label='Mean Rewards', color='red')
plt.fill_between(range(len(mean_rewards_2)), lower_bound_2, upper_bound_2, color='lightcoral', alpha=0.3, label='Standard Deviation')
plt.xlabel('Episodes')
plt.ylabel('Average Score')
plt.title('Average Score with Standard Deviation over Episodes (5 seeds)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate mean and standard deviation of rewards
mean_rewards_2 = np.mean(all_rewards, axis=0)
std_rewards_2 = np.std(all_rewards, axis=0)
upper_bound_2 = mean_rewards_2 + std_rewards_2
lower_bound_2 = mean_rewards_2 - std_rewards_2

# Plot rewards mean along with upper and lower bounds based on standard deviation
plt.figure(figsize=(10, 6))
plt.plot(mean_rewards_2, label='Mean Rewards', color='red')
plt.fill_between(range(len(mean_rewards_2)), lower_bound_2, upper_bound_2, color='lightcoral', alpha=0.3, label='Standard Deviation')
plt.xlabel('Episodes')
plt.ylabel('Average Score')
plt.title('Average Score with Standard Deviation over Episodes (5 seeds)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot rewards mean along with upper and lower bounds based on standard deviation
plt.figure(figsize=(10, 6))
plt.plot(mean_rewards_1, label='Mean Rewards Type 1', color='blue',alpha=0.5)
plt.fill_between(range(len(mean_rewards_1)), lower_bound_1, upper_bound_1, color='skyblue', alpha=0.3,label='variance of Rewards Type 1')
plt.plot(mean_rewards_2, label='Mean Rewards Type 2', color='red',alpha=0.5)
plt.fill_between(range(len(mean_rewards_2)), lower_bound_2, upper_bound_2, color='lightcoral', alpha=0.3,label='variance of Rewards Type 2')
plt.xlabel('Episodes')
plt.ylabel('Average Score')
plt.title('Average Score with Standard Deviation over Episodes (5 seeds)')
plt.legend()
plt.grid(True)
plt.show()
